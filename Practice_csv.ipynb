# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\DELL\OneDrive\Desktop\ind_nifty50list.csv')
#To check data types of all columns
print(df.dtypes)
# Out:
# Company Name    object
# Industry        object
# Symbol          object
# Series          object
# ISIN Code       object
# dtype: object

# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\DELL\OneDrive\Desktop\ind_nifty50list.csv')
df
# Out:
#                                   Company Name  \
# 0                       Adani Enterprises Ltd.
# 1   Adani Ports and Special Economic Zone Ltd.
# 2             Apollo Hospitals Enterprise Ltd.
# 3                            Asian Paints Ltd.
# 4                               Axis Bank Ltd.
# 5                              Bajaj Auto Ltd.
# 6                           Bajaj Finance Ltd.
# 7                           Bajaj Finserv Ltd.
# 8                      Bharat Electronics Ltd.
# 9                           Bharti Airtel Ltd.
# 10                                  Cipla Ltd.
# 11                             Coal India Ltd.
# 12               Dr. Reddy's Laboratories Ltd.
# 13                          Eicher Motors Ltd.
# 14                                Eternal Ltd.
# 15                      Grasim Industries Ltd.
# 16                       HCL Technologies Ltd.
# 17                              HDFC Bank Ltd.
# 18            HDFC Life Insurance Company Ltd.
# ...

# %%
#For aggregate
agg=df.pivot_table(df, index=['SYMBOL \n'], aggfunc='sum')
agg
# Out:
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_14360\651862851.py:2: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   agg=df.pivot_table(df, index=['SYMBOL \n'], aggfunc='sum')
#             %CHNG \n  30 D   %CHNG \n  CHNG \n
# SYMBOL \n
# ADANIENT       -3.71            -6.34   -88.80
# ADANIPORTS     -2.85            -6.72   -22.65
# APOLLOHOSP     -0.15            -0.40    -7.55
# ASIANPAINT     -1.22            -6.19   -37.85
# AXISBANK       -1.51            -5.30   -14.80
# BAJAJ-AUTO     -1.63             8.09   -89.30
# BAJAJFINSV     -1.72             4.50   -28.05
# BAJFINANCE      0.07             4.38     5.80
# BHARTIARTL     -0.50             3.06    -4.75
# BPCL           -0.92            -2.60    -3.20
# BRITANNIA      -1.28            -0.75   -58.70
# CIPLA          -1.21            -0.18   -14.50
# ...

# %%
import pandas as pd
df=pd.read_csv(r'C:/Users/Prakhar/Downloads/MW-NIFTY-50-24-Oct-2023.csv')
x=(df.Symbol)
y=(df.Open)
py.figure(figsize=(30,20))
py.bar(x,y)
py.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 import pandas as pd
# ----> 2 df=pd.read_csv(r'C:/Users/Prakhar/Downloads/MW-NIFTY-50-24-Oct-2023.csv')
#       3 x=(df.Symbol)
#       4 y=(df.Open)
#
# ...

# %%
x1=(df.Symbol)
y1=(df.High)
py.figure(figsize=(30,20))
py.bar(x1,y1)
py.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 x1=(df.Symbol)
#       2 y1=(df.High)
#       3 py.figure(figsize=(30,20))
#
# NameError: name 'df' is not defined

# %%
x2=(df.Symbol)
y2=(df.Low)
py.figure(figsize=(30,20))
py.bar(x2,y2)
py.show()

# %%
x3=(df.Symbol)
y3=(df['Last Traded Price'])
py.figure(figsize=(30,20))
py.bar(x3,y3)
py.show()

# %%
x4=(df.Symbol)
y4=(df.Change)
py.figure(figsize=(30,20))
py.bar(x4,y4)
py.show()

# %%
x5=(df.Symbol)
y5=(df['%Change'])
py.figure(figsize=(30,20))
py.bar(x5,y5)
py.show()

# %%
x6=(df.Symbol)
y6=(df['Traded Volume(lacs)'])
py.figure(figsize=(30,20))
py.bar(x6,y6)
py.show()

# %%
x7=(df.Symbol)
y7=(df['Traded Value(crs)'])
py.figure(figsize=(30,20))
py.bar(x7,y7)
py.show()

# %%
x8=(df.Symbol)
y8=(df['52 Week High'])
py.figure(figsize=(30,20))
py.bar(x8,y8)
py.show()

# %%
x9=(df.Symbol)
y9=(df['52 Week Low'])
py.figure(figsize=(30,20))
py.bar(x9,y9)
py.show()

# %%
x10=(df.Symbol)
y10=(df['365 Days % Change'])
py.figure(figsize=(30,20))
py.bar(x10,y10)
py.show()

# %%
x11=(df.Symbol)
y11=(df['30 Days % Change'])
py.figure(figsize=(30,20))
py.bar(x11,y11)
py.show()
