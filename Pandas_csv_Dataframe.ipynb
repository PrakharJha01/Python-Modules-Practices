# %%
import pandas as pd
a=pd.read_csv(r'C:/Users/Rahul/Downloads/task101.csv')
a
# Out:
#    Roll_no     Name    Sub
# 0        2  Prakhar  Maths
# 1       23      Ram    Eng
# 2       43   Sakshi    Phy
# 3       12    Aanya   Chem

# %%
import pandas as pd
a=pd.read_csv(r'C:/Users/Rahul/Downloads/task101.csv')
a.head(2)
# Out:
#    Roll_no     Name    Sub
# 0        2  Prakhar  Maths
# 1       23      Ram    Eng

# %%
import pandas as pd
a=pd.read_csv(r'C:/Users/Rahul/Downloads/task101.csv')
a.tail(2)
# Out:
#    Roll_no    Name   Sub
# 2       43  Sakshi   Phy
# 3       12   Aanya  Chem

# %%
import pandas as pd
l1=pd.Series(['Adit','Sakshi','Pranu','Shruti'])
l2=pd.Series(['phy','chem','maths','Ip'])
l3=pd.Series([4,3,7,8])
d1={'Name':l1,'Sub':l2,'Roll_no':l3}
a=pd.DataFrame(d1)
a
# Out:
#      Name    Sub  Roll_no
# 0    Adit    phy        4
# 1  Sakshi   chem        3
# 2   Pranu  maths        7
# 3  Shruti     Ip        8

# %%
import pandas as pd
l1=pd.Series(['Adit','Sakshi','Pranu','Shruti'])
l2=pd.Series(['phy','chem','maths','Ip'])
l3=pd.Series([4,3,7,8])
d1={'Name':l1,'Sub':l2,'Roll_no':l3}
a=pd.DataFrame(d1)
a['Name'].str[0:2]
# Out:
# 0    Ad
# 1    Sa
# 2    Pr
# 3    Sh
# Name: Name, dtype: object

# %%
import pandas as pd
d1={'Name':'Adit','Sub':'phy','Roll_no':4}
d2={'Name':'Pranu','Sub':'maths','Roll_no':45}
l=[d1,d2]
a=pd.DataFrame(l)
a
# Out:
#     Name    Sub  Roll_no
# 0   Adit    phy        4
# 1  Pranu  maths       45

# %%
import pandas as pd
a=pd.read_csv(r'C:/Users/Rahul/Downloads/task101.csv')
a[1:3]
# Out:
#    Roll_no    Name  Sub
# 1       23     Ram  Eng
# 2       43  Sakshi  Phy

# %%
import pandas as pd
a=pd.read_csv(r'C:/Users/Rahul/Downloads/task101.csv')
a[-1:-3]
# Out:
# Empty DataFrame
# Columns: [Roll_no, Name, Sub]
# Index: []

# %%
import pandas as pd
a=pd.read_csv(r'C:/Users/Rahul/Downloads/task101.csv')
a[4:2]
# Out:
# Empty DataFrame
# Columns: [Roll_no, Name, Sub]
# Index: []

# %%
import pandas as pd
a=pd.read_csv(r'C:/Users/Rahul/Downloads/task101.csv')
a[-4:-2]
# Out:
#    Roll_no     Name    Sub
# 0        2  Prakhar  Maths
# 1       23      Ram    Eng

# %%
import pandas as pd
a=pd.read_csv(r'C:/Users/Rahul/Downloads/task101.csv')
a.loc[2]
# Out:
# Roll_no        43
# Name       Sakshi
# Sub           Phy
# Name: 2, dtype: object

# %%
import pandas as pd
a=pd.read_csv(r'C:/Users/Rahul/Downloads/task101.csv')
a.iloc[3]
# Out:
# Roll_no       12
# Name       Aanya
# Sub         Chem
# Name: 3, dtype: object

# %%
import pandas as pd
a=pd.read_csv(r'C:/Users/Rahul/Downloads/task101.csv')
a.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
import pandas as pd
a=pd.read_csv(r'C:/Users/Rahul/Downloads/task101.csv')
a.columns
# Out:
# Index(['Roll_no', 'Name', 'Sub'], dtype='object')

# %%
import pandas as pd
a=pd.read_csv(r'C:/Users/Rahul/Downloads/task101.csv')
a.axes
# Out:
# [RangeIndex(start=0, stop=4, step=1),
#  Index(['Roll_no', 'Name', 'Sub'], dtype='object')]

# %%
import pandas as pd
a=pd.read_csv(r'C:/Users/Rahul/Downloads/task101.csv')
a.dtypes
# Out:
# Roll_no     int64
# Name       object
# Sub        object
# dtype: object

# %%
import pandas as pd
a=pd.read_csv(r'C:/Users/Rahul/Downloads/task101.csv')
a.size
# Out:
# 12

# %%
import pandas as pd
a=pd.read_csv(r'C:/Users/Rahul/Downloads/task101.csv')
a.shape
# Out:
# (4, 3)

# %%
import pandas as pd
a=pd.read_csv(r'C:/Users/Rahul/Downloads/task101.csv')
a.values
# Out:
# array([[2, 'Prakhar', 'Maths'],
#        [23, 'Ram', 'Eng'],
#        [43, 'Sakshi', 'Phy'],
#        [12, 'Aanya', 'Chem']], dtype=object)

# %%
import pandas as pd
a=pd.read_csv(r'C:/Users/Rahul/Downloads/task101.csv')
a.empty
# Out:
# False

# %%
import pandas as pd
a=pd.read_csv(r'C:/Users/Rahul/Downloads/task101.csv')
a.ndim
# Out:
# 2

# %%
import pandas as pd
a=pd.read_csv(r'C:/Users/Rahul/Downloads/task101.csv')
a.count()
# Out:
# Roll_no    4
# Name       4
# Sub        4
# dtype: int64

# %%
import pandas as pd
a=pd.read_csv(r'C:/Users/Rahul/Downloads/task101.csv')
a.T
# Out:
#                0    1       2      3
# Roll_no        2   23      43     12
# Name     Prakhar  Ram  Sakshi  Aanya
# Sub        Maths  Eng     Phy   Chem

# %%
import pandas as pd
a=pd.read_csv(r'C:/Users/Rahul/Downloads/task101.csv')
a[['Name','Sub']]
# Out:
#       Name    Sub
# 0  Prakhar  Maths
# 1      Ram    Eng
# 2   Sakshi    Phy
# 3    Aanya   Chem

# %%
import pandas as pd
a=pd.read_csv(r'C:/Users/Rahul/Downloads/task101.csv')
a.loc[1:3]
# Out:
#    Roll_no    Name   Sub
# 1       23     Ram   Eng
# 2       43  Sakshi   Phy
# 3       12   Aanya  Chem

# %%
import pandas as pd
a=pd.read_csv(r'C:/Users/Rahul/Downloads/task101.csv')
a.iloc[1:3]
# Out:
#    Roll_no    Name  Sub
# 1       23     Ram  Eng
# 2       43  Sakshi  Phy

# %%
import pandas as pd
a=pd.read_csv(r'C:/Users/Rahul/Downloads/task101.csv')
a.rename(index={0:1,1:2,2:3,3:4})
a.loc[1:3]
# Out:
#    Roll_no    Name   Sub
# 1       23     Ram   Eng
# 2       43  Sakshi   Phy
# 3       12   Aanya  Chem

# %%
import pandas as pd
a=pd.read_csv(r'C:/Users/Rahul/Downloads/task101.csv')
a.rename(index={0:1,1:2,2:3,3:4})
a.iloc[1:3]
# Out:
#    Roll_no    Name  Sub
# 1       23     Ram  Eng
# 2       43  Sakshi  Phy

# %%
import pandas as pd
a=pd.read_csv(r'C:/Users/Rahul/Downloads/task101.csv')
a.max()
# Out:
# Roll_no        43
# Name       Sakshi
# Sub           Phy
# dtype: object

# %%
import pandas as pd
a=pd.read_csv(r'C:/Users/Rahul/Downloads/task101.csv')
a.min()
# Out:
# Roll_no        2
# Name       Aanya
# Sub         Chem
# dtype: object

# %%
import pandas as pd
a=pd.read_csv(r'C:/Users/Rahul/Downloads/task101.csv')
a.columns=['bgy','yfgyf','buug','vygfuy']
a
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 3
#       1 import pandas as pd
#       2 a=pd.read_csv(r'C:/Users/Rahul/Downloads/task101.csv')
# ----> 3 a.columns=['bgy','yfgyf','buug','vygfuy']
#       4 a
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6002, in NDFrame.__setattr__(self, name, value)
#    6000 try:
#    6001     object.__getattribute__(self, name)
# -> 6002     return object.__setattr__(self, name, value)
#    6003 except AttributeError:
#    6004     pass
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:730, in NDFrame._set_axis(self, axis, labels)
#     725 """
#     726 This is called from the cython code when we set the `index` attribute
#     727 directly, e.g. `series.index = [1, 2, 3]`.
# ...

# %%
import pandas as pd
l1=pd.Series(['Adit','Sakshi','Pranu','Shruti'])
l2=pd.Series(['phy','chem','maths','Ip'])
l3=pd.Series([4,3,7,8])
d1={'Name':l1,'Sub':l2,'Roll_no':l3}
a=pd.DataFrame(d1)
a.index.name='sno'
a.columns.name='Details'
a
# Out:
# Details    Name    Sub  Roll_no
# sno
# 0          Adit    phy        4
# 1        Sakshi   chem        3
# 2         Pranu  maths        7
# 3        Shruti     Ip        8

# %%
import pandas as pd
l1=pd.Series(['Adit','Sakshi','Pranu','Shruti'])
l2=pd.Series(['phy','chem','maths','Ip'])
l3=pd.Series([4,3,7,8])
d1={'Name':l1,'Sub':l2,'Roll_no':l3}
a=pd.DataFrame(d1)
a['Place']=[2,4,6,8]
a
# Out:
#      Name    Sub  Roll_no  Place
# 0    Adit    phy        4      2
# 1  Sakshi   chem        3      4
# 2   Pranu  maths        7      6
# 3  Shruti     Ip        8      8

# %%
import pandas as pd
l1=pd.Series(['Adit','Sakshi','Pranu','Shruti'])
l2=pd.Series(['phy','chem','maths','Ip'])
l3=pd.Series([4,3,7,8])
d1={'Name':l1,'Sub':l2,'Roll_no':l3}
a=pd.DataFrame(d1)
a['Place']=pd.Series([2,4,6,8])
a
# Out:
#      Name    Sub  Roll_no  Place
# 0    Adit    phy        4      2
# 1  Sakshi   chem        3      4
# 2   Pranu  maths        7      6
# 3  Shruti     Ip        8      8

# %%
import pandas as pd
l1=pd.Series(['Adit','Sakshi','Pranu','Shruti'])
l2=pd.Series(['phy','chem','maths','Ip'])
l3=pd.Series([4,3,7,8])
d1={'Name':l1,'Sub':l2,'Roll_no':l3}
a=pd.DataFrame(d1)
a.insert(2,'Place',[2,4,6,8])
a
# Out:
#      Name    Sub  Place  Roll_no
# 0    Adit    phy      2        4
# 1  Sakshi   chem      4        3
# 2   Pranu  maths      6        7
# 3  Shruti     Ip      8        8

# %%
import pandas as pd
l1=pd.Series(['Adit','Sakshi','Pranu','Shruti'])
l2=pd.Series(['phy','chem','maths','Ip'])
l3=pd.Series([4,3,7,8])
d1={'Name':l1,'Sub':l2,'Roll_no':l3}
a=pd.DataFrame(d1)
a.assign(Place=[2,4,6,8])
# Out:
#      Name    Sub  Roll_no  Place
# 0    Adit    phy        4      2
# 1  Sakshi   chem        3      4
# 2   Pranu  maths        7      6
# 3  Shruti     Ip        8      8

# %%
import pandas as pd
l1=pd.Series(['Adit','Sakshi','Pranu','Shruti'])
l2=pd.Series(['phy','chem','maths','Ip'])
l3=pd.Series([4,3,7,8])
d1={'Name':l1,'Sub':l2,'Roll_no':l3}
a=pd.DataFrame(d1)
a.loc[a['Roll_no']>=5]
# Out:
#      Name    Sub  Roll_no
# 2   Pranu  maths        7
# 3  Shruti     Ip        8

# %%
import pandas as pd
a=pd.read_csv(r'C:/Users/Rahul/Downloads/task101.csv')
a.drop(2)
# Out:
#    Roll_no     Name    Sub
# 0        2  Prakhar  Maths
# 1       23      Ram    Eng
# 3       12    Aanya   Chem

# %%
a.sum()
# Out:
# Roll_no                       80
# Name       PrakharRamSakshiAanya
# Sub              MathsEngPhyChem
# dtype: object

# %%
a.describe()
# Out:
#          Roll_no
# count   4.000000
# mean   20.000000
# std    17.568912
# min     2.000000
# 25%     9.500000
# 50%    17.500000
# 75%    28.000000
# max    43.000000

# %%
a.count()
# Out:
# Roll_no    4
# Name       4
# Sub        4
# dtype: int64

# %%
import pandas as pd
a=pd.read_csv(r'C:/Users/Rahul/Downloads/task101.csv')
a['class'].mode()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'class'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[71], line 3
# ...

# %%
a.quantile(q=0.4,axis=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 a.quantile(q=0.4,axis=0)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10882, in DataFrame.quantile(self, q, axis, numeric_only, interpolation, method)
#   10875 axis = self._get_axis_number(axis)
#   10877 if not is_list_like(q):
#   10878     # BlockManager.quantile expects listlike, so we wrap and unwrap here
#   10879     # error: List item 0 has incompatible type "Union[float, Union[Union[
#   10880     # ExtensionArray, ndarray[Any, Any]], Index, Series], Sequence[float]]";
#   10881     # expected "float"
# > 10882     res_df = self.quantile(  # type: ignore[call-overload]
#   10883         [q],
#   10884         axis=axis,
#   10885         numeric_only=numeric_only,
#   10886         interpolation=interpolation,
#   10887         method=method,
#   10888     )
# ...
